# %%
# !pip install datasets sentence-transformers bertopic
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.3.0)
# Collecting bertopic
#   Downloading bertopic-0.17.4-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (5.0.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.10.0+cpu)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.8.41)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.5.11)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: llvmlite>0.36.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.43.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan>=0.8.29->bertopic) (1.5.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=4.7.0->bertopic) (9.1.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (0.1.2)
# Downloading bertopic-0.17.4-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: bertopic
# Successfully installed bertopic-0.17.4

# %%
from datasets import load_dataset

dataset = load_dataset("yelp_review_full", split="train")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# yelp_review_full/train-00000-of-00001.pa(…):   0%|          | 0.00/299M [00:00<?, ?B/s]
# yelp_review_full/test-00000-of-00001.par(…):   0%|          | 0.00/23.5M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/650000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
df = dataset.to_pandas()
df = df.sample(20000, random_state=42)
df.head()
# Out:
#         label                                               text
# 177288      0  First of all i'm not a big fan of buffet, i tr...
# 238756      1  Thanks Yelp. I was looking for the words to de...
# 604225      2  Service was so-so. They were receiving a deliv...
# 2838        2  Stamoolis Brothers is one of the Strip Distric...
# 586957      0  I want to give a 2 stars because the service s...

# %%
df = df.dropna(subset=["text"])
df["text"] = df["text"].str.lower()

# %%
print("orginalshape:", dataset)
print("smaple shape:", df.shape)
# Out:
# orginalshape: Dataset({
#     features: ['label', 'text'],
#     num_rows: 650000
# })
# smaple shape: (20000, 2)

# %%
df.info()
df.isnull().sum()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, 177288 to 390980
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   20000 non-null  int64
#  1   text    20000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 468.8+ KB
# label     int64
# text     object
# dtype: object

# %%
df["label"].value_counts()
# Out:
# label
# 2    4039
# 0    4035
# 3    4017
# 1    3958
# 4    3951
# Name: count, dtype: int64

# %%
from collections import Counter

words = " ".join(df["text"]).split()
Counter(words).most_common(20)
# Out:
# [('the', 133461),
#  ('and', 84889),
#  ('i', 69330),
#  ('a', 68696),
#  ('to', 66115),
#  ('was', 48580),
#  ('of', 40142),
#  ('for', 30899),
#  ('it', 29840),
#  ('is', 29813),
#  ('in', 29220),
#  ('that', 24025),
#  ('my', 22904),
#  ('but', 21786),
#  ('we', 20235),
#  ('with', 20178),
#  ('this', 20054),
#  ('they', 19435),
#  ('on', 18207),
#  ('not', 17893)]

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def clean_text(text):
    words = text.split()
    words = [w for w in words if w not in ENGLISH_STOP_WORDS]
    return " ".join(words)

df["clean_text"] = df["text"].apply(clean_text)

# %%
df["clean_text"]
# Out:
# 177288    i'm big fan buffet, tried got $50 credit stayi...
# 238756    thanks yelp. looking words place meh fitting.\...
# 604225    service so-so. receiving delivery it. food hot...
# 2838      stamoolis brothers strip district storefronts,...
# 586957    want 2 stars service staff friendly good ambie...
#                                 ...
# 188178    it's beautiful appearance, reminds younger, ha...
# 574411    went fusion pizza try new place. love business...
# 575952    cancelled membership june, signed months train...
# 237244    yikes...their standards dropped 2 years ago. d...
# 390980    terrace really makes place. it's pretty cool, ...
# Name: clean_text, Length: 20000, dtype: object

# %%
texts = df["clean_text"].tolist()

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

embeddings = model.encode(
    texts,
    show_progress_bar=True
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]

# %%
from bertopic import BERTopic

topic_model = BERTopic()

topics, probs = topic_model.fit_transform(texts, embeddings)
# Out:
# /usr/local/lib/python3.12/dist-packages/hdbscan/robust_single_linkage_.py:175: SyntaxWarning: invalid escape sequence '\{'
#   $max \{ core_k(a), core_k(b), 1/\alpha d(a,b) \}$.

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                       Name  \
# 0       -1   8675                    -1_food_good_place_like
# 1        0   1030                 0_mexican_tacos_salsa_taco
# 2        1    835                    1_room_hotel_stay_rooms
# 3        2    470             2_pizza_crust_pizzas_pepperoni
# 4        3    457                    3_sushi_roll_rolls_tuna
# ..     ...    ...                                        ...
# 153    152     10  152_portions_crocketts_sharedthey_portion
# 154    153     10          153_gelato_scoops_flavors_nutella
# 155    154     10                  154_zia_music_cds_records
# 156    155     10            155_frys_computer_employees_buy
# 157    156     10               156_tavern_mina_grill_expect
#
#                                         Representation  \
# 0    [food, good, place, like, just, service, time,...
# 1    [mexican, tacos, salsa, taco, burrito, chips, ...
# 2    [room, hotel, stay, rooms, stayed, desk, bed, ...
# 3    [pizza, crust, pizzas, pepperoni, slice, toppi...
# 4    [sushi, roll, rolls, tuna, nigiri, fish, ayce,...
# ..                                                 ...
# 153  [portions, crocketts, sharedthey, portion, goo...
# 154  [gelato, scoops, flavors, nutella, 535, scoop,...
# 155  [zia, music, cds, records, equipment, gc, drum...
# 156  [frys, computer, employees, buy, store, apple,...
# 157  [tavern, mina, grill, expect, rollatini, halib...
#
#                                    Representative_Docs
# 0    [reading reviews place, cautiously optimistic ...
# 1    [looking decent mexican restaurant strip came ...
# 2    [stayed wigwam 4 days \"adobe traditional suit...
# 3    [great pizza great price fresh pizza wonderful...
# 4    [don't understand place getting positive revie...
# ..                                                 ...
# 153  [good food really stingy portions price- 3+ do...
# 154  [camelback greenway. yummy!! best gelato phx.....
# 155  [harmony house music great place shop music ne...
# 156  [shopping store opened. service usually ranges...
# 157  [good hopes restaurant, end fell flat.\n\nfirs...
#
# [158 rows x 5 columns]

# %%
topic_model = topic_model.reduce_topics(texts)

# %%
topic_info = topic_model.get_topic_info()
topic_info.head(10)
# Out:
#    Topic  Count                            Name  \
# 0     -1   8675         -1_food_good_place_like
# 1      0   8429          0_food_good_place_like
# 2      1    725         1_club_music_dance_show
# 3      2    579         2_hair_nails_nail_salon
# 4      3    540       3_car_told_service_called
# 5      4    200         4_massage_gym_spa_class
# 6      5    187     5_airport_flight_car_rental
# 7      6    150            6_car_wash_clean_job
# 8      7    141  7_doctor_dr_office_appointment
# 9      8    108                8_et_le_la_u00e0
#
#                                       Representation  \
# 0  [food, good, place, like, just, service, time,...
# 1  [food, good, place, like, just, great, its, re...
# 2  [club, music, dance, show, like, its, just, pl...
# 3  [hair, nails, nail, salon, cut, gel, pedicure,...
# 4  [car, told, service, called, said, customer, t...
# 5  [massage, gym, spa, class, classes, fitness, e...
# 6  [airport, flight, car, rental, parking, airlin...
# 7  [car, wash, clean, job, place, cleaners, dirty...
# 8  [doctor, dr, office, appointment, insurance, t...
# 9  [et, le, la, u00e0, und, des, est, pour, une, ...
#
#                                  Representative_Docs
# 0  [review strictly location only! love applebees...
# 1  [soooo disappointed visit ever!! understand ob...
# 2  [simply amazing!! cirque du soleil show, boy d...
# 3  [i'd say i'm pretty disappointed one. reading ...
# 4  [car died, originally towed ruffing close car ...
# 5  [avid spa go-er vegas favorite place pampered....
# 6  [time flying vegas... bit shock slot machines ...
# 7  [got car washed 3 months ago twice price car w...
# 8  [you're really sick need doctor, elsewhere! ex...
# 9  [pas mal du tout ce petit resto ramen dans chi...

# %%
for topic in topic_info["Topic"][:8]:  # top 8 topics
    if topic == -1:
        continue

    print("\nTopic:", topic)
    print("Keywords:", topic_model.get_topic(topic))
    print("Sample Reviews:", topic_model.get_representative_docs(topic)[:2])
# Out:
# Topic: 0
# Keywords: [('food', np.float64(0.020384665383774203)), ('good', np.float64(0.019253868617432217)), ('place', np.float64(0.018236178326115293)), ('like', np.float64(0.01565824751105195)), ('just', np.float64(0.015252802683991852)), ('great', np.float64(0.013610188860258884)), ('its', np.float64(0.012982141538690237)), ('really', np.float64(0.012641459597336984)), ('service', np.float64(0.01233051479218388)), ('time', np.float64(0.011957120991664082))]
# Sample Reviews: ['soooo disappointed visit ever!! understand obsession marie callender frozen pot pies. fall winter michigan, ate day, favorite honey chicken pot pie. just heat micro did want wait hour cook oven. microwaved pie flakey bake oven, better chicken pot pie ate night marie callender\'s restaurant! \\n\\ni craving pot pie 3 decided best. walked felt like oven, heat high thought ovens broke baking food heat vents. friendly lady counter said \\"they\\" employees complaining \\"cold\\"....i employees happy, happy work environment makes better service\\" \\n\\nbut come on, sw
# Keywords: [('car', np.float64(0.037615405696102236)), ('told', np.float64(0.02085722271647086)), ('service', np.float64(0.019221678385256843)), ('called', np.float64(0.017658255979980036)), ('said', np.float64(0.017013665947236713)), ('customer', np.float64(0.015651062842410596)), ('time', np.float64(0.015236882867947296)), ('store', np.float64(0.014889743342057862)), ('day', np.float64(0.014424250518684902)), ('phone', np.float64(0.013589425160422568))]
# Sample Reviews: ['car died, originally towed ruffing close car broke down. saw good reviews, figured it\'d worth shot, surprised awful people were.\\n\\nruffing originally suggested car dealer, it\'s uncommon model didn\'t know problem was. asked just pay vehicle diagnostic, they\'re likely honest dealership. said day-and-a-half it.\\n\\nalmost days later, hadn\'t heard them. need car daily basis, frustrating past quoted time updates going on. repairs time - diagnostic.\\n\\nmy biggest issue attitude received called. called delay, mechanic agitated. tone condescending told it\'s fault leaving car -- just look going elsewhere. said cars sitting weeks hasn\'t touched (?) can\'t bother mine. ultimately car towed dealership anyway, couldn\'t afford car sit shop \\"weeks\\".\\n\\ni wished logged were, trying schedule couldn\'t abide by, stress followed them.\\n\\ni wouldn\'t recommend mechanic anyone. you\'re better going realistic wait-times communication. definitely don\'t want deal mechanic going lose cool drop hat.', "apartments nice located right greenbelt near old town scottsdale. dealt worse customer service apartments rented.\\ni came saturday waited 20 minutes talk employee working. casually taking time couple, expected, failed greet offer literature waited. showing model, went talk favorite foods trips overseas, sense urgency help out. finally left, answered phone tended tenants walked in, giving attention all.\\nthere follow shown model. liked location figured there. time called, leave message, answered phone. day me.\\ni handed application, girl called day. happy customer service man. all. said days application process came back. did not. called day, course leave message. returned call. couple times hold her. sent lease email dates wrong, emailed back. returned emails. told wanted apartment day moved make sure wanted signing lease. called, returned messages emails asking this. got temporary assistant line said do, manager gone home day. \\nso day suppose in, went complex. figured customer service lousy perspective customer, needed fixed, having problems with. 2 hours, looked apartment, filled application, signed lease, moved in! best thing chazal, location, good makes apartment properties look!\\noh, course, sort follow ask hadn't moved day suppose chazal...."]
#
# Topic: 4
# Keywords: [('massage', np.float64(0.0758970006591154)), ('gym', np.float64(0.06451764498045563)), ('spa', np.float64(0.030234815731852827)), ('class', np.float64(0.023811904261563755)), ('classes', np.float64(0.02323289423460055)), ('fitness', np.float64(0.021685372549809852)), ('equipment', np.float64(0.021190187324598323)), ('membership', np.float64(0.01930044950972342)), ('work', np.float64(0.018685932657539935)), ('room', np.float64(0.017272124482238315))]
# Sample Reviews: ["avid spa go-er vegas favorite place pampered. \\n\\nwe staying hard rock opted couple's massage reliquary. couple's massage nice just pick massage list services set couple's room. plus spa does co-ed warm jacuzzi pool co-ed lounge. got deep tissue massage good. therapist listened needs applied appropriate pressure. hard good deep massage vegas (for reason), place great one! \\n\\nbeyond massage rest place ok. like said co-ed areas, nice have, exactly luxurious. women's spa tiny hot tub, 2 person dry sauna large steam room. clean, small kind forgettable. locker room shower area adequate, special. necessities nice enough. however, didn't swim suit dryer (which odd), just big roll plastic bags suit home in. honestly, spa vegas gone saw 1 person locker room (no else). \\n\\nthe price steep, vegas. stay hotel coupon $25 service backstage pass (player's card) 10% off. actually gripes management spa. did confirm appointment (i actually called make sure books). secondly, make sign receipts payment massage room (totally ruins vibe). lastly, biggest worrisome gripe charged us. walked receipt price agreed upon, checked charges spa did make charged room. tell there, took days remedy situation - really left bad taste mouth. \\n\\nso stay hard rock need quick break, try massage, sure watch bill! ok, really want quality experience suggest caesar's qua.", 'stopped foot massage place expecting just foot massage, actually offered pretty thorough neck massage well. therapist tina strong hands. soaked feet bucket sort warm tea water. massage feet soothing comfortable. then, came body massage. tina did wonders neck, arms, back. prefer strong pressure massage exactly received. spent lot time massage greatly appreciated that. massage comparable receive large spa, fraction price. think paid $50 1 hour. strongly recommend place comes vegas looking legitimate massage, like receive establishments large neon signs.']
#
# Topic: 5
# Keywords: [('airport', np.float64(0.0708819691684979)), ('flight', np.float64(0.056573053525245984)), ('car', np.float64(0.036516586573975975)), ('rental', np.float64(0.029939602211194308)), ('parking', np.float64(0.02639387916626514)), ('airline', np.float64(0.025798548451910784)), ('cab', np.float64(0.02161109031372916)), ('flights', np.float64(0.017538994631667613)), ('driver', np.float64(0.017489266038906028)), ('shuttle', np.float64(0.017096023175362667))]
# Sample Reviews: ["time flying vegas... bit shock slot machines airport... it's vegas. airport fairly modern kept. gate numbers did quite flow pockets branches, map sense.\\n\\ni guess sections airport old - newer portion airport. leave lot time schedule flight flying weekend. mad rush airport catch flights reality. gate right boarding started worked me, flights easily missed stuck waiting taxi waiting dropped good point taxi.", "sit airport, i'd like share experience wait 3.5 hours delayed flight depart.\\n\\nyou making huge mistake contemplate flying allegiant. fall victim false affordable prices. listed price $75 round trip escalated $150 additional charges (carry luggage, reserving seats...). paid additional fees 5pm flight, incompetent airline just let 7pm vegas flight leave us. \\n\\nthis airline stresses need arrive exaggerated time flight, took work vacation time year drive 50 min airport middle nowhere. 5pm staff terminal explain flight boarded. allegiant doesn't staff here, just oblivous rude airport staff deal customers.\\n\\nwe saw allegiant manager 5 min cowered angry mob, offered apologies compensation. retreated sad cave doubt unqualified loser again. \\n\\ni'm currently surrounded passengers waiting different 4:10 flight leave, currently 6:45. poorly air conditioned terminal phone having cancel/reschedule plans airline airports inability execute flights daily.\\n\\ni fly time work liesure; worse experience. act together, return flight near awful... \\n\\nf u allegiant airport\\n\\nps: airline stress measure, allow smoke f-ing cigarette anywhere!"]
#
# Topic: 6
# Keywords: [('car', np.float64(0.07764217067358026)), ('wash', np.float64(0.07520748024797737)), ('clean', np.float64(0.026573755176037696)), ('job', np.float64(0.02626631809388134)), ('place', np.float64(0.02428650959595932)), ('cleaners', np.float64(0.024183549261128017)), ('dirty', np.float64(0.0236784525335367)), ('cleaning', np.float64(0.022613687961037732)), ('dont', np.float64(0.021755511964416458)), ('cleaned', np.float64(0.021541389636549564))]
# Sample Reviews: ['got car washed 3 months ago twice price car washes area did pretty sloppy job. thought maybe bad day decided second chance today (9/21/13). today worse time. car pretty clean just dusty washed couple weeks. said ready looked inside forgot wipe inside car. dash dust, interior door panels wiped cup holders hadn\'t touched. tipped employee cleaned went car. asked employee clean rag wipe interior. i\'m doing manager, younger white guy buzz cut comes says to: \\"get car there\\". told didn\'t wipe inside car gives dirty pissed look, closes door just walks off. won\'t time, choices there. don\'t know owner upper management reads reviews want pass management line check employees work rude customers pay $22.00 dollars pretty substandard car wash.', "location twice, boss asked car specifically basic wash inside out. employees nice enough, reason i'm giving place 1 star. vaguely remember bringing car year ago quite disappointed interior specifically, happened time around. kidding say looked like didn't vacuum inside all, deluxe car wash. addition, time went, finished cleaning car, drove car really weird area middle gas station parking lot didn't tell (we ones sitting outside). awkward having middle cleaning cars ask keys. $18, felt like wasted boss's money. outside looked better, better account $18. keeps asking bring car here, don't it. dollar car wash vacuum myself, look better!"]

# %% [markdown]
# ### Key Insights from Yelp Customer Reviews
#
# 1. Food & Restaurant Experience (Most Discussed Topic)
#    - Customers frequently talk about food quality, taste, and overall dining experience.
#    - This is the most dominant topic, indicating that restaurants are the primary focus of reviews.
#
# 2. Entertainment & Nightlife
#    - Reviews include experiences related to clubs, music, dance shows, and nightlife activities.
#    - Customers evaluate atmosphere, crowd, and overall enjoyment.
#
# 3. Beauty & Salon Services
#    - Customers discuss haircuts, nail services, and salon experiences.
#    - Feedback includes service quality, hygiene, and pricing.
#
# 4. Automotive Services
#    - Reviews highlight issues with car repair, customer service, and communication.
#    - Many complaints relate to delays and poor service handling.
#
# 5. Health & Wellness Services
#    - Includes gyms, spas, massages, and fitness centers.
#    - Customers focus on service quality and facilities.
#
# 6. Travel & Airport Experience
#    - Reviews mention airport services, flights, and transportation.
#    - Common issues include delays and service dissatisfaction.
#
# 7. Car Cleaning & Maintenance Services
#    - Customers discuss car wash quality and cleanliness.
#    - Complaints often relate to incomplete or poor cleaning.

# %%
topic_info = topic_model.get_topic_info()

# Remove outlier topic (-1)
filtered = topic_info[topic_info["Topic"] != -1]

# Sort by count
filtered = filtered.sort_values(by="Count", ascending=False)

filtered.head()
# Out:
#    Topic  Count                       Name  \
# 1      0   8429     0_food_good_place_like
# 2      1    725    1_club_music_dance_show
# 3      2    579    2_hair_nails_nail_salon
# 4      3    540  3_car_told_service_called
# 5      4    200    4_massage_gym_spa_class
#
#                                       Representation  \
# 1  [food, good, place, like, just, great, its, re...
# 2  [club, music, dance, show, like, its, just, pl...
# 3  [hair, nails, nail, salon, cut, gel, pedicure,...
# 4  [car, told, service, called, said, customer, t...
# 5  [massage, gym, spa, class, classes, fitness, e...
#
#                                  Representative_Docs
# 1  [soooo disappointed visit ever!! understand ob...
# 2  [simply amazing!! cirque du soleil show, boy d...
# 3  [i'd say i'm pretty disappointed one. reading ...
# 4  [car died, originally towed ruffing close car ...
# 5  [avid spa go-er vegas favorite place pampered....

# %% [markdown]
# Most Discussed Topic:
# Food and restaurant-related reviews dominate the dataset,
# indicating that dining experiences are the most frequently discussed by customers.

# %%
filtered[["Topic", "Count"]]
# Out:
#     Topic  Count
# 1       0   8429
# 2       1    725
# 3       2    579
# 4       3    540
# 5       4    200
# 6       5    187
# 7       6    150
# 8       7    141
# 9       8    108
# 10      9     90
# 11     10     30
# 12     11     28
# 13     12     26
# 14     13     24
# 15     14     20
# 16     15     14
# 17     16     13
# 18     17     11
# 19     18     10

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28bada2a-28ce-4aaa-b050-ff3cf068f56e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28bada2a-28ce-4aaa-b050-ff3cf068f56e")) {                    Plotly.newPlot(                        "28bada2a-28ce-4aaa-b050-ff3cf068f56e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015252802683991852,0.01565824751105195,0.018236178326115293,0.019253868617432217,0.020384665383774203],"y":["just  ","like  ","place  ","good  ","food  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.018270583002817926,0.0189224866502009,0.021553276902836323,0.02220147858272187,0.03091873463796391],"y":["like  ","show  ","dance  ","music  ","club  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.024294089041948855,0.025937623149051854,0.02859387072790919,0.03806790022561255,0.04388228928948242],"y":["cut  ","salon  ","nail  ","nails  ","hair  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.017013665947236713,0.017658255979980036,0.019221678385256843,0.02085722271647086,0.037615405696102236],"y":["said  ","called  ","service  ","told  ","car  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.02323289423460055,0.023811904261563755,0.030234815731852827,0.06451764498045563,0.0758970006591154],"y":["classes  ","class  ","spa  ","gym  ","massage  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02639387916626514,0.029939602211194308,0.036516586573975975,0.056573053525245984,0.0708819691684979],"y":["parking  ","rental  ","car  ","flight  ","airport  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.02428650959595932,0.02626631809388134,0.026573755176037696,0.07520748024797737,0.07764217067358026],"y":["place  ","job  ","clean  ","wash  ","car  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.028024950342443358,0.035086231560947756,0.03974545890952905,0.040753244533319966,0.044380137525184084],"y":["insurance  ","appointment  ","office  ","dr  ","doctor  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555 ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0313f429-1327-46a1-a7b6-4988d0e63473" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0313f429-1327-46a1-a7b6-4988d0e63473")) {                    Plotly.newPlot(                        "0313f429-1327-46a1-a7b6-4988d0e63473",                        [{"customdata":[[0,"food | good | place | like | just",8429],[1,"club | music | dance | show | like",725],[2,"hair | nails | nail | salon | cut",579],[3,"car | told | service | called | said",540],[4,"massage | gym | spa | class | classes",200],[5,"airport | flight | car | rental | parking",187],[6,"car | wash | clean | job | place",150],[7,"doctor | dr | office | appointment | insurance",141],[8,"et | le | la | u00e0 | und",108],[9,"dog | vet | pet | dogs | cat",90],[10,"great | service | friendly | staff | customer",30],[11,"yuck | anymore | good | sylish | spookey",28],[12,"bike | bikes | shop | mechanic | tune",26],[13,"pros | 24 | staff | place | food",24],[14,"range | gun | guns | shooting | rifle",20],[15,"school | class | teachers | education | teacher",14],[16,"plumbing | water | company | chris | aquapro",13],[17,"windows | tinted | tint | elias | window",11],[18,"music | zia | cds | equipment | records",10]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[8429,725,579,540,200,187,150,141,108,90,30,28,26,24,20,14,13,11,10],"sizemode":"area","sizeref":5.268125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15.438488,15.58453,10.740898,10.344623,10.945415,9.937044,9.531151,8.761552,15.099647,9.116987,10.24482,9.909679,10.479006,15.236363,13.8652,11.000683,9.108597,9.807063,14.140218],"xaxis":"x","y":[-1.0538988,-0.52319044,12.519709,13.998342,12.074499,13.750393,14.059381,12.985403,-0.87756467,12.295505,14.5053425,14.701226,13.479321,-1.2945124,0.24340941,12.031382,13.708739,13.076188,0.102432676],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.77777777777 ...

# %% [markdown]
# ### Conclusion
#
# This project demonstrates how unstructured customer reviews can be transformed into meaningful insights using NLP techniques such as embeddings and topic modeling.
#
# The analysis reveals key customer concerns and dominant themes, helping businesses better understand customer feedback and improve services.
